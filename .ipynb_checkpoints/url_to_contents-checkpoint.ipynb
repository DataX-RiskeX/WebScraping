# %%
# https://altair-viz.github.io/case_studies/exploring-weather.html
# look into this once you get started with EDA
# conda install -c conda-forge altair

# %%
## Import Packages and Libraries ##

# Web parcing, scraping, etc.
import bs4 as bs # BeautifulSoup4 
import urllib3
import re
import requests # HTTP parser
import html5lib

# DataFrames and math
import pandas as pd
import numpy as np

# Output related packages 
import pprint as pp

# read-in and write-out
import csv

# %%
# stretch Jupyter coding blocks to fit screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>")) 

# make it run on py2 and py3
from __future__ import division, print_function
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # Data Mining II
# This  notebook is intended to perform the following processes:
#
#     2.1 Read-in batched csv files and perform content extraction.
#
#     2.2 The notebook uses beautifulsoup to extract paragraph content of each url in batch.
#
#     2.3 Content extraction is written out as a matching csv file for future concatenation/merging

# %% [markdown]
# ___
# ### **Begin Data Mining II:** Per-url, article content extraction

# %% [markdown]
# __2.1 Read-in batched csv files and perform content extraction.__

# %%
# Extract all .csv elements in folder
import glob
csv_all = glob.glob('*.csv') # elements of list are string name for each .csv file
csv_all
# Out:
# ['rawData_6.csv',
#  'rawData_7.csv',
#  'rawData_5.csv',
#  'rawData_4.csv',
#  'rawData_0.csv',
#  'rawData_1.csv',
#  'rawData_3.csv',
#  'rawData_2.csv',
#  'rawData_9.csv',
#  'rawData_8.csv']

# %% [markdown]
# __2.2 Use beautifulsoup to extract paragraph content of each url in batch.__

# %% [markdown]
# #### Function: **get_article**
# get_artilcle controls two function that extract the contents of a given url -- by accessing the paragraphs.

# %%
def validate_site(site):
    from urllib.parse import urlparse
    import copy
    url = copy.copy(site) 
    
    # urlparse requires a string 
    info = urlparse(str(url))
    if 'mp3' in info.path:            # validates that site is not a podcast
        return('')                    # flagged for removal
    else:
        return(url)

# %%
def get_content(site):
    src = requests.get(site).content            # accesses content of html object
    soup = bs.BeautifulSoup(src, 'lxml')        # object creation used in extracting paragraphs using built-in html parser
    body = soup.find_all('p')                   # finds all paragraphs '<p>' in html object
    return(body)

# %%
def extract_from_content(body):
    sentence = [parags.text for parags in body]
    text = "\t".join(sentence)                  # tab delimeter for easier extraction
    return(text)

# %%
def get_article(site):
    valid_site = validate_site(site)
    if not valid_site:
        return('.mp3: Invalid Type')                # uses 'falsy' check if string is empty 
    else:
        body = get_content(valid_site)
        text = extract_from_content(body)
        if not text:                                # uses 'falsy' check if string is empty 
            return('403 Forbidden')
    return(text)

# %% [markdown]
# #### Function: **get_text**
# Function loops over all urls and creates a list to be appended to newsDF.

# %%
def get_text(df):
    """
    Accepts a 6xn dataframe and returns a 1xn list and a modifed dataframe
    Note: stitching a dataframes to a list is much faster that updating existing one with a new column
    """
    import copy

    content = []
    url = []
    author = copy.copy(df['author'])
    link = copy.copy(df['source_url'])

    for name in author:
       
        if name == 'Ml-implode.com': 
            r = requests.get(link)
            soup = bs.BeautifulSoup(r.text, 'html.parser')
            source = soup.find(id="LIJIT_title")            # manually found -- may differ moving forward
            link = source.find('a').get('href')             # gets the 'href inside the a tag -- i.e. the correct url
            url.append(link)
            content.append(get_article(link))               # send correct url out for extraction
        
        else:
            content.append(get_article(link))
        
    return({'url':url, 'content':content})

# %% [markdown]
# #### Function: **combine_df**
# Function sends list of urls to get_text and get_articles for content extraction. Function then combines all data into a single dataframe.

# %%
def combine_df(df1, df2):
    import copy
    author = copy.deepcopy(df1['author'])
    df = copy.deepcopy(df1)
    df['contents'] = "".join(df2['content']) # converts list to string
    
    # catches aggregator names and replaces them with that of the buplisher
    #checks for know aggregator, replaces it with the url referenced by aggregator
    for i in range(len(df)):
        if author == 'Ml-implode.com':
            df['source_url'] = "".join(df2['url']) # converts 'list' item to 'str' item
    return(df)

# %%
def replace_author_name(df):
    from urllib.parse import urlparse
    import copy
    #data = copy(df)
    url = copy.copy(df) 
    
    # urlparse requires a string 
    info = urlparse(str(url))
    return(info.netloc)          #.netloc extract the main url -- i.e. excludes path

# %%
# Replace 'None' values
def rm_false_author(df):
    """
     Receives pandas datraframe, and removes aggregator name from author feature
    """
    author = df['author']
    source = df['source_url']
    publisher = df['publisher']
    
    #checks for know aggregator, replaces it with the url referenced by aggregator
    for i in range(len(df)):
        if author.loc[i] == 'Ml-implode.com':
            author.loc[i] = replace_author_name(source.loc[i])  # parameter is correct url as type 'str'
            publisher.loc[i] = author.loc[i]                    #replaces instances of incorrect publisher name
    return(df)

# %%
def stitch_df(df):
    import copy
    df = copy.deepcopy(df)
    data = pd.DataFrame()
    
    # for-loop merges dataframes and calls other functions that provide dataframe with data
    for i in range(len(df)):
        df1 = copy.deepcopy(df.loc[i])
        df2 = get_text(df1)
        datum = data.append(combine_df(df1,df2))
        
        ## minor clean up ##
        # optional: data = data.drop(columns=['description'])     # removes redundant column        
        data = rm_false_author(datum)                             # replaces invalid author entry
    return(data)

# %% [markdown]
# __do something__

# %%
# Removes rows with inaccessible data
def rm_site_error(df):
    """
     Receives pandas datraframe, and removes rows containing data not accessible by BeautifulSoup
    """
    import copy
    data = copy.deepcopy(df)
    content = data['contents']
    for i in range(len(content)):
        if content.loc[i] == '403 Forbidden':
            print("Error Found: 403 Forbidden --> Dropping site from dataframe...")
            # df.drop(df.index[[1,3]])
            data.drop([i], axis = 0, inplace = True)
            #df = data[data.index != '403 Forbidden']
            #print(data.index[i], type(data.index[i]))
            #iris.ix[iris['sepal length (cm)'] >= 5]
            #data = df.ix[df['contents'] == '403 Forbidden' ]
        elif content.loc[i] == '.mp3: Invalid Type':
            print("Error Found: .mp3 Invalid Type --> Dropping site from dataframe...")
            data.drop([i], axis = 0, inplace = True)
    return(data)

# %%
#takes list of the csv-s, reads them and outputs list of df-s
def make_lst_dfs(lst_csv):
    lst_dfs = []
    for i in lst_csv:
        df= pd.read_csv(i)
        lst_dfs.append(df)
    return lst_dfs

# %% [markdown]
# #### Completed Process:
# ##### riskEx_df represents a dataframe of extracted features, their values, and the text content of each article's body
#
# __The following cell has an approximate run time of:__
# #### **5 HOURS**
#
# Use *riskEx_df.csv* or *riskEx_df.json* instead.

# %%
def control(lst):
    for item in range(len(lst)):
        print(item, lst[item])
        
        extract_this = stitch_df(lst[item])
        clean_this = rm_site_error(exract_this) 
        item.to_csv('riskEx_{id}.csv'.format(id=id), index_label = False)
#    for id, df_i in  enumerate(np.array_split(df, batchSize)):

# %%
csv_all_dfs = make_lst_dfs(csv_all)
stitch_df(csv_all_dfs[4][:5])
# Out:
# http://www.sandiegouniontribune.com/business/real-estate/sd-fi-purplebricks-launch-20180108-story.html
# P <class 'str'>
# h <class 'str'>
# i <class 'str'>
# l <class 'str'>
# l <class 'str'>
# i <class 'str'>
# p <class 'str'>
#   <class 'str'>
# M <class 'str'>
# o <class 'str'>
# l <class 'str'>
# n <class 'str'>
# a <class 'str'>
# r <class 'str'>
# http://ml-implode.com/staticnews/2018-01-09_WhyAfricanmillennialscantgetenoughofBitcoin.html
# M <class 'str'>
# l <class 'str'>
# - <class 'str'>
# i <class 'str'>
# m <class 'str'>
# p <class 'str'>
# l <class 'str'>
# o <class 'str'>
# d <class 'str'>
# e <class 'str'>
# . <class 'str'>
# c <class 'str'>
# o <class 'str'>
# m <class 'str'>
# http://www.bostonherald.com/news/national/2018/01/kodak_surges_at_it_becomes_latest_cryptocurrency_convert
# A <class 'str'>
# s <class 'str'>
# s <class 'str'>
# o <class 'str'>
# c <class 'str'>
# i <class 'str'>
# a <class 'str'>
# t <class 'str'>
# e <class 'str'>
# d <class 'str'>
#   <class 'str'>
# P <class 'str'>
# r <class 'str'>
# e <class 'str'>
# s <class 'str'>
# s <class 'str'>
# , <class 'str'>
#   <class 'str'>
# B <class 'str'>
# y <class 'str'>
#   <class 'str'>
# A <class 'str'>
# s <class 'str'>
# s <class 'str'>
# o <class 'str'>
# c <class 'str'>
# i <class 'str'>
# a <class 'str'>
# t <class 'str'>
# e <class 'str'>
# d <class 'str'>
#   <class 'str'>
# P <class 'str'>
# r <class 'str'>
# e <class 'str'>
# s <class 'str'>
# s <class 'str'>
# http://ml-implode.com/staticnews/2018-01-09_DimonIregretcallingbitcoinafraud.html
# M <class 'str'>
# l <class 'str'>
# - <class 'str'>
# i <class 'str'>
# m <class 'str'>
# p <class 'str'>
# l <class 'str'>
# o <class 'str'>
# d <class 'str'>
# e <class 'str'>
# . <class 'str'>
# c <class 'str'>
# o <class 'str'>
# m <class 'str'>
# http://ml-implode.com/staticnews/2018-01-09_FundmanagerssaybitcoinETFproposalswithdrawnduetoSECconcerns.html
# M <class 'str'>
# l <class 'str'>
# - <class 'str'>
# i <class 'str'>
# m <class 'str'>
# p <class 'str'>
# l <class 'str'>
# o <class 'str'>
# d <class 'str'>
# e <class 'str'>
# . <class 'str'>
# c <class 'str'>
# o <class 'str'>
# m <class 'str'>
# http://ml-implode.com/staticnews/2018-01-09_Bitcoinfascinatingbecauseperceptionofriskandtheeconomyischanging.html
# M <class 'str'>
# l <class 'str'>
# - <class 'str'>
# i <class 'str'>
# m <class 'str'>
# p <class 'str'>
# l <class 'str'>
# o <class 'str'>
# d <class 'str'>
# e <class 'str'>
# . <class 'str'>
# c <class 'str'>
# o <class 'str'>
# m <class 'str'>
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1660     def _getitem_tuple(self, tup):
#    1661
# -> 1662         self._has_valid_tuple(tup)
#    1663         try:
#    1664             return self._getitem_lowerdim(tup)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     189             if not self._has_valid_type(k, i):
#     190                 raise ValueError("Location based indexing can only have [%s] "
# --> 191                                  "types" % self._valid_types)
#     192
#     193     def _should_validate_iterable(self, axis=0):
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
control(csv_all_dfs)
# Out:
#                                                 author  \
# 600                                     Phillip Molnar
# 601                                     Ml-implode.com
# 602              Associated Press, By Associated Press
# 603                                     Ml-implode.com
# 604                                     Ml-implode.com
# 605                                     Ml-implode.com
# 606                                          itokoichi
# 607                                          Yahoo.com
# 608                                    The Star Online
# 609                                         kodiak1120
# 610                                     Ashley Boucher
# 611                                       Tyler Durden
# 612                                      Reid Nakamura
# 613                           newsfeeds@nzherald.co.nz
# 614                                   Elizabeth Gurdus
# 615                                         Tom Krazit
# 616                                         Sam DeBord
# 617                                John Stanley Hunter
# 618                                dgooley@zscaler.com
# 619                                         Python.org
# 620                                        Sylvan Lane
# 621                                        IAN McGUGAN
# 622                                          Topix.com
# 623                                          Topix.com
# 624                                       Michelle Fox
# 625                                         Bitcoinist
# 626                                      Will Michaels
# 627                                       Nikhilesh De
# 628                       Jai Vijayan Freelance writer
# 629                                     James Rickards
# ..                                                 ...
# 670                                   James Mickleboro
# 671                                           alexmark
# 672                                         Aviva Patz
# 673                                   Matthieu Poletti
# 674                                      Mark Matousek
# 675                                      Eren Sengezer
# 676                                       Tyler Durden
# 677                   The Motley Fool, The Motley Fool
# 678                                        Paul Ausick
# 679                                         Joe Ciolli
# 680                                      Zachary Riley
# 681                                        Google News
# 682                                       Tyler Durden
# 683                                      Graham Rapier
# 684  Lorenzo Franceschi-Bicchierai, Jordan Pearson,...
# 685                                       Stan Higgins
# 686                                          Anonymous
# 687                   CoinTelegraph By Rakesh Upadhyay
# 688                                         Paul Vigna
# 689                                          Juan Buis
# 690            newsfeedback@fool.com (Matthew Frankel)
# 691                                      Jared Dillian
# 692                                        David Floyd
# 693                                         Joe Ciolli
# 694                                          Hvper.com
# 695                                          Yahoo.com
# 696  http://www.dailymail.co.uk/home/search.html?s=...
# 697                                     Danny Crichton
# 698                                          Yahoo.com
# 699                                        Dapper Apps
#
#                                            description  \
# 600  A British real estate company Monday launched ...
# 601  ``In parts of the continent - especially comme...
# 602  NEW YORK — Kodak, which traces its roots to th...
# 603  ``JPMorgan Chase CEO Jamie Dimon has walked ba...
# 604  ``Staff at the regulatory agency "expressed co...
# 605  ``People are pouring money into bitcoin and ot...
# 606  https://smhn.info/201801-microsoft-stop-pay-wi...
# 607  Jim Cramer gauged the speculative potential of...
# 608  Check out these exclusives in your newspaper t...
# 609  This is a simple box that is designed to hold ...
# 610  Shows in the Shondaland universe like “Grey’s ...
# 611  Authored by Liberty Blitzkrieg's Mike Krieger ...
# 612  Paul William Davis explained his decision to r...
# 613  Once a joke bitcoin alternative, Dogecoin is n...
# 614  Jim Cramer gauged the speculative potential of...
# 615  Cloud users and data center managers began to ...
# 616  Bitcoin and cryptocurrency offer fascinating o...
# 617  Lucas Jackson/Reuters Wall Streeters are getti...
# 618  Overview: This is the seventh in a series of b...
# 619  A JavaScript / Python / PHP cryptocurrency tra...
# 620  Trump promises farmers a 'better deal' on NAFT...
# 621  Stay conservative and you may miss out on big ...
# 622  So, Bitcoin is soaring and very few people und...
# 623  Bitcoin and other cryptocurrencies, although n...
# 624  The cryptocurrency market may be just what is ...
# 625  The cryptocurrency market is at an all-time hi...
# 626  A Republican state lawmaker is teaming up with...
# 627  South Korea's financial regulators began inspe...
# 628  A malware tool for stealthily installing softw...
# 629  This post Has Jim Rickards Changed His Mind on...
# ..                                                 ...
# 670  The Ripple (XRP) price had one of its worst da...
# 671                                                NaN
# 672  Thanks to technological advances that have res...
# 673  The most advanced cryptocurrency exchange to b...
# 674  Toyota revealed a self-driving concept vehicle...
# 675  After starting the previous week on a positive...
# 676  It's official - 2018 is a lock for stock inves...
# 677  Are you considering investing in gold to prote...
# 678  UnitedHealth, Disney, Pfizer, and General Elec...
# 679  US stocks climbed higher, led by technology sh...
# 680  The meteoric rise of bitcoin and the idea of c...
# 681  Debating is at the core of a robust society — ...
# 682  Authored by Ian King via BanyanHill.com, Bitco...
# 683  Shares of Western Union continued to climb Mon...
# 684  Developers left the vulnerability unpatched fo...
# 685  Chinese bitcoin mining pool ViaBTC has announc...
# 686  Talis Putnins and Jonathan Karlsen, Professors...
# 687    New week, new..volatility wave? #PRICE ANALYSIS
# 688  Prices for some of the most popular cryptocurr...
# 689  This is story is brought to you by Hacker Noon...
# 690  Ethereum is once again the second-largest cryp...
# 691  The yields are too low, given that the ECB wil...
# 692  The changes to the federal tax code in late 20...
# 693  GoPro short sellers made roughly $45 million i...
# 694  The Internet on one page. Successor of Popurls...
# 695         Wow. Such blockchain, much cryptocurrency.
# 696  By Saqib Iqbal AhmedNEW YORK, Jan 8 (Reuters) ...
# 697  Debating is at the core of a robust society — ...
# 698  A data adjustment by CoinMarketCap caused cryp...
# 699                                   View on Dribbble
#
#                     publisher  \
# 600  Sandiegouniontribune.com
# 601            Ml-implode.com
# 602          Bostonherald.com
# 603            Ml-implode.com
# 604            Ml-implode.com
# 605            Ml-implode.com
# 606              Hatena.ne.jp
# 607                 Yahoo.com
# 608            Thestar.com.my
# 609           Thingiverse.com
# 610               Thewrap.com
# 611             Zerohedge.com
# 612               Thewrap.com
# 613            Nzherald.co.nz
# 614                      CNBC
# 615              Geekwire.com
# 616                 Inman.com
# 617          Business Insider
# 618               Zscaler.com
# 619                Python.org
# 620                  The Hill
# 621        The Globe And Mail
# 622                 Topix.com
# 623                 Topix.com
# 624                      CNBC
# 625            Bitcoinist.com
# 626                  Wunc.org
# 627              Coindesk.com
# 628           Darkreading.com
# 629        Dailyreckoning.com
# ..                        ...
# 629  This post Has Jim Rickards Changed His Mind on...
# ..                                                 ...
# 670  The Ripple (XRP) price had one of its worst da...
# 671                                                NaN
# 672  Thanks to technological advances that have res...
# 673  The most advanced cryptocurrency exchange to b...
# 674  Toyota revealed a self-driving concept vehicle...
# 675  After starting the previous week on a positive...
# 676  It's official - 2018 is a lock for stock inves...
# 677  Are you considering investing in gold to prote...
# 678  UnitedHealth, Disney, Pfizer, and General Elec...
# 679  US stocks climbed higher, led by technology sh...
# 680  The meteoric rise of bitcoin and the idea of c...
# 681  Debating is at the core of a robust society — ...
# 682  Authored by Ian King via BanyanHill.com, Bitco...
# 683  Shares of Western Union continued to climb Mon...
# 684  Developers left the vulnerability unpatched fo...
# 685  Chinese bitcoin mining pool ViaBTC has announc...
# 686  Talis Putnins and Jonathan Karlsen, Professors...
# 687    New week, new..volatility wave? #PRICE ANALYSIS
# 688  Prices for some of the most popular cryptocurr...
# 689  This is story is brought to you by Hacker Noon...
# 690  Ethereum is once again the second-largest cryp...
# 691  The yields are too low, given that the ECB wil...
# 692  The changes to the federal tax code in late 20...
# 693  GoPro short sellers made roughly $45 million i...
# 694  The Internet on one page. Successor of Popurls...
# 695         Wow. Such blockchain, much cryptocurrency.
# 696  By Saqib Iqbal AhmedNEW YORK, Jan 8 (Reuters) ...
# 697  Debating is at the core of a robust society — ...
# 698  A data adjustment by CoinMarketCap caused cryp...
# 699                                   View on Dribbble
#
#                     publisher  \
# 600  Sandiegouniontribune.com
# 601            Ml-implode.com
# 602          Bostonherald.com
# 603            Ml-implode.com
# 604            Ml-implode.com
# 605            Ml-implode.com
# 606              Hatena.ne.jp
# 607                 Yahoo.com
# 608            Thestar.com.my
# 609           Thingiverse.com
# 610               Thewrap.com
# 611             Zerohedge.com
# 612               Thewrap.com
# 613            Nzherald.co.nz
# 614                      CNBC
# 615              Geekwire.com
# 616                 Inman.com
# 617          Business Insider
# 618               Zscaler.com
# 619                Python.org
# 620                  The Hill
# 621        The Globe And Mail
# 622                 Topix.com
# 623                 Topix.com
# 624                      CNBC
# 625            Bitcoinist.com
# 626                  Wunc.org
# 627              Coindesk.com
# 628           Darkreading.com
# 629        Dailyreckoning.com
# ..                        ...
# 670               Fool.com.au
# 671   Investmentwatchblog.com
# 672                    Rd.com
# 673                Hitbtc.com
# 674          Business Insider
# 675              Fxstreet.com
# 676             Zerohedge.com
# 677                  Fool.com
# 678             247wallst.com
# 679          Business Insider
# 680             Valuewalk.com
# 681               Google News
# 682             Zerohedge.com
# 683          Business Insider
# 684                 Vice News
# 685              Coindesk.com
# 686            Deepdotweb.com
# 687         Cointelegraph.com
# 688   The Wall Street Journal
# 689            Hackernoon.com
# 690                  Fool.com
# 691           Marketwatch.com
# 692          Investopedia.com
# 693          Business Insider
# 694                 Hvper.com
# 695                 Yahoo.com
# 696                Daily Mail
# 697                TechCrunch
# 698                 Yahoo.com
# 699              Dribbble.com
#
#                                             source_url            timeStamp  \
# 600  http://www.sandiegouniontribune.com/business/r...  2018-01-09 00:00:00
# 625  Is The Meteoric Rise In Cryptocurrencies Trigg...
# 626  NC Proposal Takes Aim At Recent Cyber Attacks ...
# 627  South Korean Banks Face Scrutiny Over Crypto E...
# 628  New Cryptocurrency Mining Malware Has Links to...
# 629      Has Jim Rickards Changed His Mind on Bitcoin?
# ..                                                 ...
# 670                The Ripple (XRP) price just crashed
# 671  Morgan Stanley WARNS Of Coming Recession & Sto...
# 672  16 Money Mistakes Millennials Don’t Realize Th...
# 673  HitBTC — Trade cryptocurrencies with the lowes...
# 674  Toyota unveiled a crazy-looking self-driving v...
# 675  Crypto Today: Bitcoin slides toward $15K, Ripp...
# 676  Ripple Rebounds After Rout As S&P Gains 'Guara...
# 677   Inflation hedge? 3 myths about investing in gold
# 678          UnitedHealth, Disney Weigh on DJIA Monday
# 679  STOCKS CLIMB HIGHER: Here's what you need to know
# 680  Warnings From China And Israel Cause Bitcoin P...
# 681  It’s a walrus! No, it’s a giraffe! No, it’s Mi...
# 682                 Bitcoin - The End Of The Beginning
# 683  Western Union keeps climbing after unconfirmed...
# 684  Electrum Bitcoin Wallets Were Vulnerable to Ha...
# 685  ViaBTC Announces Shutdown of Crypto Mining Con...
# 686  Research: 47% Of All Bitcoin Transactions Invo...
# 687  Bitcoin, Ethereum, Bitcoin Cash, Ripple, IOTA,...
# 688  Crypto Website Changes Data -- $100 Billion in...
# 689  How the $170 million Ethereum bug could have b...
# 690  Bitcoin and Ripple Are Falling While Ethereum ...
# 691         European bonds are the No. 1 risk for 2018
# 692       How the New Tax Law Impacts Cryptocurrencies
# 693  GoPro's plunging stock made short sellers $45 ...
# 694  99% of These Sea Turtles Are Turning FemaleHer...
# 695  Dogecoin: How a Parody Cryptocurrency Hit $2 B...
# 696           FOREX-Dollar gains as euro rally falters
# 697  It’s a walrus! No, it’s a giraffe! No, it’s Mi...
# 698  Here’s why cryptocurrencies are getting smoked...
# 699                          The Bitcoin Startup Story
#
# [100 rows x 6 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-5648b6df8977> in <module>()
# ----> 1 control(csv_all_dfs)
#
# <ipython-input-25-888a1abbcfd6> in control(lst)
#       2     for item in lst:
#       3         print(item, item)
# ----> 4         df = pd.read_csv(item)
#       5         print(df)
#       6         extract_this = stitch_df(df)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     390     compression = _infer_compression(filepath_or_buffer, compression)
#     391     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 392         filepath_or_buffer, encoding, compression)
#     393     kwds['compression'] = compression
#     394
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     208     if not is_file_like(filepath_or_buffer):
#     209         msg = "Invalid file path or buffer object type: {_type}"
# --> 210         raise ValueError(msg.format(_type=type(filepath_or_buffer)))
#     211
#     212     return filepath_or_buffer, None, compression
#
# ValueError: Invalid file path or buffer object type: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# __2.3 Write out content as matching csv file for future concatenation/merging__

# %% [markdown]
# __Note:__ *riskEx_df* object is a 7xn DataFrame containing the following:
#
# All data from *newsDF* object. The content of the object *text*, column-appended according to the indices of newsDF.

# %% [markdown]
# ### **End Data Mining II:** Per-url, article content extraction
# ___
